# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

import os
import copy

import numpy as np 

from astropy.io import fits
from astropy.table import Table, Column

import matplotlib.pyplot as plt

# %%
from kungpao.display import display_single

# %% [markdown]
# ## Learn about the CCD "raw" data of the DECaLS survey

# %%
data_dir = '/Users/song/Downloads/merian/'

decals_dir = os.path.join(data_dir, 'decals')

# %%
brick_test = '1933m005'

ccd_data = os.path.join(decals_dir, brick_test, 'ccd')

# %%
band = 'r'

ccd_test = os.path.join(ccd_data, band, 'decam-425341-S29-r_img.fits')

# %%
_ = display_single(fits.open(ccd_test)[1].data)

# %%
fits.open(ccd_test)[0].header
# Out:
# SIMPLE  =                    T / file does conform to FITS standard
# BITPIX  =                   16 / number of bits per data pixel
# NAXIS   =                    0 / number of data axes
# EXTEND  =                    T / FITS dataset may contain extensions
# COMMENT   FITS (Flexible Image Transport System) format is defined in 'Astronomy
# COMMENT   and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H
# DATE    = '2015-03-30T23:27:23' / Date FITS file was generated
# IRAF-TLM= '2015-03-31T05:42:01' / Time of last modification
# ORIGIN  = 'NOAO-IRAF FITS Image Kernel July 2003' / FITS file originator
# OBJECT  = 'DECaLS_44950_r'     / Name of the object observed
# COMMENT   FITS (Flexible Image Transport System) format is defined in 'Astronomy
# COMMENT   and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H
# PROCTYPE= 'InstCal '           / Data processing level
# PRODTYPE= 'image   '           / Data product type
# PIXSCAL1=                 0.27 / [arcsec/pixel] Pixel scale, axis 1
# PIXSCAL2=                 0.27 / [arcsec/pixel] Pixel scale, axis 2
# OBS-LONG=             70.81489 / [deg] Observatory east longitude
# TELESCOP= 'CTIO 4.0-m telescope' / Telescope name
# OBSERVAT= 'CTIO    '           / Observatory name
# OBS-LAT =            -30.16606 / [deg] Observatory latitude
# OBS-ELEV=                2215. / [m] Observatory elevation
# INSTRUME= 'DECam   '           / Instrument used to obtain these data
# EXPREQ  =                  48. / [s] Requested exposure duration
# EXPTIME =                  48. / [s] Exposure duration
# DARKTIME=           49.1083999 / [s] Dark time
# OBSID   = 'ct4m20150328t052056' / Unique Observation ID
# DATE-OBS= '2015-03-28T05:20:56.667009' /  UTC epoch
# TIME-OBS= '05:20:56.667009'    / Time of observation start (UTC)
# MJD-OBS =       57109.22287809 / MJD of observation start
# OPENSHUT= '2015-03-28T05:20:56.717940' / Time when shutter opened (UTC)
# TIMESYS = 'UTC     '           / Time system
# EXPNUM  =               425341 / DECam exposure number
# OBSTYPE = 'object  '           / Observation type
# CAMSHUT = 'Open    '           / Camera shutter at exposure start
# PROGRAM = 'The DECam Legacy Survey of the SDSS Equatorial Sky' / Current observi
# OBSERVER= 'Patej, Schlegel, Rudnick' / Observer name(s)
# PROPOSER= 'Schlegel'           / Proposal Principle Investigator
# DTPI    = 'Schlegel          ' /  Principal Investigator
# PROPID  = '2014B-0404'         / Proposal ID
# EXCLUDED= '        '           / DECam components not used for this frame
# SEQID   =                    2 / Sequence name
# SEQNUM  =                    1 / Number of image in sequence
# SEQTOT  =                   28 / Total number of images in sequence
# AOS     =                    T / AOS data available if true
# BCAM    =                    F / BCAM data available if true
# GUIDER  =                    1 / Guider (0-absent,1-ok,2-lost star,3-los
# SKYSTAT =                    T / Cloud camera (RASICAM) available if true
# FILTER  = 'r DECam SDSS c0002 6415.0 1480.0' / Unique filter identifier
# FILTPOS = 'cassette_4'         / Filter position in FCM
# INSTANCE= 'DECam_20150327'     / SISPI instance name
# ERRORS  =                      / SISPI readout errors
# TELEQUIN=                2000. / Equinox of telescope coordinates
# TELSTAT = 'Track   '           / Telescope tracking status
# RA      = '12:54:01.75'        / [HH:MM:SS] Target RA
# DEC     = '-1:35:10.6'         / [DD:MM:SS] Target DEC
# TELRA   = '12:54:01.498'       / [HH:MM:SS] Telescope RA
# TELDEC  = '-01:35:02.800'      / [DD:MM:SS] Telescope DEC
# HA      = '00:04:14.380'       / [HH:MM:SS] Telescope hour angle
# ZD      =                28.51 / [deg] Telescope zenith distance
# AZ      =             357.9969 / [deg] Telescope azimuth angle
# DOMEAZ  =                3.201 / [deg] Dome azimuth angle
# TELFOCUS= '-592.58,-2229.85,2790.95,82.46,-75.17,-0.0' / DECam hexapod settings
# VSUB    =                    T / True if CCD substrate voltage is on
# GSKYPHOT=                    F / RASICAM global sky clear flag
# LSKYPHOT=                    T / RASICAM local sky clear flag
# WINDSPD =               11.587 / [m/s] Wind speed
# WINDDIR =                 325. / [deg] Wind direction (from North)
# HUMIDITY=                  48. / [%] Ambient relative humidity (outside)
# PRESSURE=                 781. / [Torr] Barometric pressure (outside)
# DIMMSEE = 'NaN     '           / [arcsec] DIMM Seeing
# OUTTEMP =                 11.9 / [deg C] Outside temperature
# AIRMASS =                 1.14 / Airmass
# GSKYVAR =                 0.04 / RASICAM global sky standard deviation
# GSKYHOT =                 0.07 / RASICAM global sky fraction above threshold
# LSKYVAR =                 0.01 / RASICAM local sky standard deviation
# LSKYHOT =                   0. / RASICAM local sky fraction above threshold
# LSKYPOW =                 0.02 / RASICAM local sky normalized power
# MSURTEMP=                 10.5 / [deg C] Mirror surface average temperature
# MAIRTEMP=                  11. / [deg C] Mirror temperature above surface
# UPTRTEMP=               12.471 / [deg C] Upper truss average temperature
# LWTRTEMP= 'NaN     '           / [deg C] Lower truss average temperature
# PMOSTEMP=                 10.8 / [deg C] Mirror top surface temperature
# UTN-TEMP=                12.38 / [deg C] Upper truss temperature north
# UTS-TEMP=               12.455 / [deg C] Upper truss temperature south
# UTW-TEMP=               12.735 / [deg C] Upper truss temperature west
# UTE-TEMP=               12.315 / [deg C] Upper truss temperature east
# PMN-TEMP=                  10. / [deg C] Mirror north edge temperature
# PMS-TEMP=                 10.4 / [deg C] Mirror south edge temperature
# PMW-TEMP=                 10.5 / [deg C] Mirror west edge temperature
# PME-TEMP=                 11.1 / [deg C] Mirror east edge temperature
# DOMELOW =               13.255 / [deg C] Low dome temperature
# DOMEHIGH=                 12.5 / [deg C] High dome temperature
# DOMEFLOR=                  9.9 / [deg C] Dome floor temperature
# G-MEANX =               0.1613 / [arcsec] Guider x-axis mean offset
# G-MEANY =               -0.018 / [arcsec] Guider y-axis mean offset
# DONUTFS4= '1.82,1.14,-8.59,-0.04,-0.09,-0.11,-0.06,-0.02,-0.24' / Mean Wavefr
# DONUTFS3= '1.02,1.67,9.02,0.0,0.12,0.0,0.03,0.03,-0.34' / Mean Wavefront fo
# DONUTFS2= '1.55,0.43,-8.63,0.12,-0.02,-0.12,-0.04,0.22,0.0' / Mean Wavefront
# DONUTFS1= '0.52,1.52,9.04,0.16,0.4,0.05,-0.03,0.25,0.1' / Mean Wavefront fo
# G-FLXVAR=          6571817.581 / [arcsec] Guider mean guide star flux variances
# G-MEANXY=             -0.00663 / [arcsec2] Guider (xy) 2nd moment mean offset
# DONUTFN1= '        '           / Mean Wavefront for Sensor FN1
# DONUTFN2= '1.29,1.97,9.21,-0.33,0.25,0.04,0.01,0.25,0.07' / Mean Wavefront fo
# DONUTFN3= '0.69,0.8,-8.45,-0.25,-0.04,-0.08,-0.06,0.1,0.3' / Mean Wavefron
# DONUTFN4= '1.51,1.58,8.97,-0.1,0.05,0.03,-0.03,-0.05,0.3' / Mean Wavefront
# HIERARCH TIME_RECORDED = '2015-03-28T05:22:06.878084'
# G-FEEDBK= '10,5    '           / [%] Guider feedback (HA, dec)
# G-CCDNUM=                    4 / Number of guide CCDs that remained active
# DOXT    =                 -0.1 / [arcsec] X-theta from donut analysis
# G-MAXX  =               0.6721 / [arcsec] Guider x-axis maximum offset
# FADZ    =               -46.22 / [um] FA Delta focus.
# FADY    =               -62.54 / [um] FA Delta Y.
# FADX    =                80.51 / [um] FA Delta X.
# G-MODE  = 'auto    '           / Guider operation mode
# FAYT    =               -28.84 / [arcsec] FA Delta Y-theta.
# DODZ    =               -46.22 / [um] Delta-Z from donut analysis
# DODY    =                 -1.2 / [um] Y-decenter from donut analysis
# DODX    =                 -1.3 / [um] X-decenter from donut analysis
# MULTIEXP=                    F / Frame contains multiple exposures if true
# SKYUPDAT= '2015-03-28T05:17:58' / Time of last RASICAM exposure (UTC)
# G-SEEING=                2.835 / [arcsec] Guider average seeing
# G-TRANSP=                0.526 / Guider average sky transparency
# G-MEANY2=             0.048241 / [arcsec2] Guider (y) 2nd moment mean offset
# DOYT    =                 0.06 / [arcsec] Y-theta from donut analysis
# G-LATENC=                1.272 / [s] Guider avg. latency between exposures
# LUTVER  = 'v20150102'          / Hexapod Lookup Table version
# FAXT    =                15.08 / [arcsec] FA Delta X-theta.
# G-MAXY  =               0.4071 / [arcsec] Guider y-axis maximum offset
# G-MEANX2=             0.063102 / [arcsec2] Guider (x) 2nd moment mean offset
# SISPIVER= 'trunk   '           / SISPI software version
# CONSTVER= 'DECAM:54'           / SISPI constants version
# HDRVER  =                   13 / DECam fits header version
# DTSITE  = 'ct                ' /  observatory location
# DTTELESC= 'ct4m              ' /  telescope identifier
# DTINSTRU= 'decam             ' /  instrument identifier
# DTCALDAT= '2015-03-27        ' /  calendar date from observing schedule
# ODATEOBS= '                  ' /  previous DATE-OBS
# DTUTC   = '2015-03-28T05:22:33' /  post exposure UTC epoch from DTS
# DTOBSERV= 'NOAO              ' /  scheduling institution
# DTPROPID= '2014B-0404        ' /  observing proposal ID
# DTPIAFFL= '                  ' /  PI affiliation
# DTTITLE = '                  ' /  title of observing proposal
# DTCOPYRI= 'AURA              ' /  copyright holder of data
# DTACQUIS= 'pipeline2.ctio.noao.edu' /  host name of data acquisition computer
# DTACCOUN= 'sispi             ' /  observing account name
# DTACQNAM= '/data_local/images/DTS/2014B-0404/DECam_00425341.fits.fz' /  file na
# DTNSANAM= 'c4d_150328_052233_ori.fits' /  file name in NOAO Science Archive
# DT_RTNAM= 'c4d_150328_052233_ori' /  NSA root name
# DTQUEUE = 'decam             ' /  DTS queue (83682)
# DTSTATUS= 'done              ' /  data transport status
# SB_HOST = 'dec01.tuc.noao.edu' /  iSTB client host
# SB_ACCOU= 'lp                ' /  iSTB client user account
# SB_SITE = 'tu                ' /  iSTB host site
# SB_LOCAL= 'tu                ' /  locale of iSTB daemon
# SB_DIR1 = 'Q20150330         ' /  level 1 directory in NSA DS
# SB_DIR2 = 'DEC15A            ' /  level 2 directory in NSA DS
# SB_DIR3 =             20150326 /  level 3 directory in NSA DS
# SB_RECNO=              3014872 /  iSTB sequence number
# SB_ID   = 'tu3014872         ' /  unique iSTB identifier
# SB_NAME = 'c4d_150328_052233_ooi_r_v1.fits' /  name assigned by iSTB
# SB_RTNAM= 'c4d_150328_052233_ori' /  NSA root name
# RMCOUNT =                    1 /  remediation counter
# RECNO   =              3014872 /  NOAO Science Archive sequence number
# BUNIT   = 'adu     '           / Brightness units for pixel array
# DETSIZE = '[1:29400,1:29050]'  / Detector size
# CCDSEC  = '[1:2048,1:4096]'    / CCD section to display
# CCDBIN1 =                    1 / Pixel binning, axis 1
# CCDBIN2 =                    1 / Pixel binning, axis 2
# DHEINF  = 'MNSN fermi hardware' / DHE Hardware
# DHEFIRM = 'demo30  '           / DHE Firmware
# RADESYS = 'FK5     '           / World coordinate reference frame
# EQUINOX =                2000. / Equinox
# VALIDA  =                    T / Data from amp A is valid
# VALIDB  =                    T / Data from amp B is valid
# NDONUTS =                    0 / AOS number of donuts analyzed for this CCD
# PHOTFLAG=                    0 / Night Photometric (1) or not (0)
# XTALKFIL= 'xtalk_20130606.txt' / Crosstalk file
# HISTORY DESDM: /data/sharedfs/deccp/CP_INSTALL/cp223/bin/DECam_crosstalk /data/s
# HISTORY haredfs/deccp/Archive/DEC15A/src/57108r/src/dec288811.fits /data/sharedf
# HISTORY s/deccp/Archive/DEC15A/red/20150330105218_57108r/raw/dec288811/dec288811
# HISTORY  -verbose 3 -crosstalk /data/sharedfs/deccp/Archive/CAL/cal/DECamMasterC
# HISTORY al_56475/xtalk/xtalk_20130606.txt -postsatmask -replace /data/sharedfs/d
# HISTORY eccp/Archive/CAL/cal/DECamMasterCal_56475/hfix/hfix_20130628.txt -photfl
# HISTORY ag 0 -overscansample 1 -overscanfunction 0 -overscanorder 1 -overscantri
# HISTORY m 5
# HISTORY DESDM: /data/sharedfs/deccp/CP_INSTALL/cp223/bin/imcorrect /data/sharedf
# HISTORY t -output /data/sharedfs/deccp/Archive/DEC15A/red/20150330105218_57108r/
# HISTORY edfs/deccp/Archive/CAL/cal/DECamMasterCal_56475/linearity/linearity_tabl
# HISTORY e_v0.4.fits -bias /data/sharedfs/deccp/Archive/CAL/cal/20150330093530_57
# HISTORY en /data/sharedfs/deccp/Archive/CAL/cal/20150330102411_57108rF/flatcor/D
# HISTORY ta/sharedfs/deccp/Archive/CAL/cal/DECamMasterCal_56876/starflat/DECam_Ma
# HISTORY rbose 3 -interpolate_col 2.0 -fast -noisemode FULL
# HISTORY DESDM: /data/sharedfs/deccp/CP_INSTALL/cp223/bin/mkbleedmask -i -b 5 -f
# HISTORY 1.0 -l 7 -n 7 -r 5 -s 40 -t 20 -v 3 -y 1.0 -E 5 /data/sharedfs/deccp/Arc
# HISTORY ata/sharedfs/deccp/Archive/DEC15A/red/20150330105218_57108r/red/dec28881
# DES_EXT = 'IMAGE   '           / Image extension
# SCAMPCHI=                  7.1 / chi2 value from SCAMP
# SCAMPFLG=                    0 / Flag for SCAMP; 0=no WARNING; 1=WARNING exists
# SCAMPNUM=                 3554 / number of matched stars from SCAMP
# RADECSYS= 'ICRS    '           / Astrometric system
# HISTORY DESDM: /data/sharedfs/deccp/CP_INSTALL/cp223/bin/maskcosmics /data/share
# HISTORY dfs/deccp/Archive/DEC15A/red/20150330105218_57108r/red/dec288811/dec2888
# MAGZERO =               29.152 / [mag] Magnitude zero point
# MAGZPT  =      24.948896906561 / [mag] Magnitude zero point per sec
# PHOTREF = 'PS1     '           / Photometric ref. catalog
# PUPILSKY=             172.2073
# PUPILMAX=             1.830671
# PUPILAMP=           0.01063062
# SKYSUB  =             171.9695
# NEXTEND =                    2
# FILENAME= 'DEC15A_20150326_8828bc0-r-20150328T052056_oi'
# PLVER   = 'V3.6.1  '
# PLDNAME = 'DEC15A_20150326_8828bc0'
# PLQUEUE = 'DEC15A  '
# PLQNAME =             20150326
# PLPROCID= '8828bc0 '
# PLFNAME = 'DEC15A_20150326_8828bc0-r-20150328T052056_oi'
# WCSCAL  = 'Successful'         / Astrometric calibration
# PLDSID  = 'c4d_150328_052233_ooi_r_v1' / PL NSA name
# PLARVER =                    1 / PL NSA archive version
